# %%
# Task: Write a program

# Q> create and import below files

# 1. Create a friend_names.xls file  (atleast 10 names, columns are FriendName,Quality)
# Q1> create a dataframe which contains only your intelligent friends list.
# Q2> create a dataframe which contains only your funny friends list.

# %%
# 1. Create a friend_names.xls file  (atleast 10 names, columns are FriendName,Quality)
import pandas as pd
df_friends=pd.read_excel(r"C:\jaya sri\Assignments\Jayasri\Pandas_assign9\freindsquality.xlsx")
df_friends
# Out:
#      friends    Qualities
# 0   Nasheena  Intelligent
# 1      Durga   Irritating
# 2   Santhosh  Intelligent
# 3     swathi        Funny
# 4     Parvin          Don
# 5    Shabana     Innocent
# 6   Jayasree    Developer
# 7     Anusha         Good
# 8     Reshma        Funny
# 9  Nagadurga  Intelligent

# %%
# Q1> create a dataframe which contains only your intelligent friends list.

# %%
df_friends_q1=df_friends[df_friends['Qualities']=="Intelligent"]
df_friends_q1
# Out:
#      friends    Qualities
# 0   Nasheena  Intelligent
# 2   Santhosh  Intelligent
# 9  Nagadurga  Intelligent

# %%
# Q2> create a dataframe which contains only your funny friends list.

# %%
df_friends_q2=df_friends[df_friends['Qualities']=='Funny']
df_friends_q2
# Out:
#   friends Qualities
# 3  swathi     Funny
# 8  Reshma     Funny

# %%
# 2. Create a family_members.xls file  (atleast 10 names, columns are FamilyMemberName*Relation)
family_members=pd.read_excel(r"C:\jaya sri\Assignments\Jayasri\Pandas_assign9\family_members.xlsx")
family_members
# Out:
#   Family_members_Name Relation
# 0        Janardhnarao  Parents
# 1             Lakshmi  Parents
# 2          Rajasekhar  brother
# 3         balakrishna  brother
# 4             mounika   sister
# 5         himamounika   sister
# 6             likitha   sister

# %%
# Q1> create a dataframe which contains only your brothers and sisters list.
lst=["brother","sister"]
family_members[family_members.Relation.isin(lst)]
# Out:
#   Family_members_Name Relation
# 2          Rajasekhar  brother
# 3         balakrishna  brother
# 4             mounika   sister
# 5         himamounika   sister
# 6             likitha   sister

# %%
# Q2> create a dataframe which contains only your parents list.
family_members[family_members['Relation']=="Parents"]
# Out:
#   Family_members_Name Relation
# 0        Janardhnarao  Parents
# 1             Lakshmi  Parents

# %%
# Q3> create a dataframe which not contains your parents list.
family_members[family_members['Relation']!="Parents"]
# Out:
#   Family_members_Name Relation
# 2          Rajasekhar  brother
# 3         balakrishna  brother
# 4             mounika   sister
# 5         himamounika   sister
# 6             likitha   sister

# %%
# Q4> create a dataframe which not contains your brothers list.
family_members[family_members['Relation']!="brother"]
# Out:
#   Family_members_Name Relation
# 0        Janardhnarao  Parents
# 1             Lakshmi  Parents
# 4             mounika   sister
# 5         himamounika   sister
# 6             likitha   sister

# %%
# Q5> create a dataframe which contains either your brothers list or parents list.
family_members[(family_members['Relation']=="brother") | (family_members['Relation']=='Parents')]
# Out:
#   Family_members_Name Relation
# 0        Janardhnarao  Parents
# 1             Lakshmi  Parents
# 2          Rajasekhar  brother
# 3         balakrishna  brother

# %%
# 3. Create a Vegfood_items.xlsx file  (atleast 10 names, columns are VegFoodName*Taste)
import pandas as pd
df_vegfood=pd.read_excel(r"C:\jaya sri\Assignments\Jayasri\pandas_assign10\vegfoodtaste.xlsx")
df_vegfood
# Out:
#         vegfood  taste
# 0        paneer  curry
# 1          aloo    fry
# 2      babycorn    fry
# 3      vegpulav    fry
# 4    gobimasala  curry
# 5  paneermasala   soup
# 6     mealmaker   soup

# %%
# Q1>create a dataframe which are  soups items
df_vegfood[df_vegfood['taste']=="soup"]
# Out:
#         vegfood taste
# 5  paneermasala  soup
# 6     mealmaker  soup

# %%
# Q2>create a dataframe which are curry items
df_vegfood[df_vegfood['taste']=="curry"]
# Out:
#       vegfood  taste
# 0      paneer  curry
# 4  gobimasala  curry

# %%
# Q3>create a dataframe which are fry items
df_vegfood[df_vegfood['taste']=="fry"]
# Out:
#     vegfood taste
# 1      aloo   fry
# 2  babycorn   fry
# 3  vegpulav   fry

# %%
# Q4>create a dataframe which contains soups and fry items
lst1=['soup','fry']
df_vegfood[df_vegfood.taste.isin(lst1)]
# Out:
#         vegfood taste
# 1          aloo   fry
# 2      babycorn   fry
# 3      vegpulav   fry
# 5  paneermasala  soup
# 6     mealmaker  soup

# %%
# Q5>create a dataframe which not contains soups and fry items
lst1=['soup','fry']
df_vegfood[~df_vegfood.taste.isin(lst1)]
# Out:
#       vegfood  taste
# 0      paneer  curry
# 4  gobimasala  curry

# %%
# Q6>create a dataframe which contains either soup or fry items
df_vegfood[(df_vegfood['taste']=='soup') | (df_vegfood['taste']=='fry')]
# Out:
#         vegfood taste
# 1          aloo   fry
# 2      babycorn   fry
# 3      vegpulav   fry
# 5  paneermasala  soup
# 6     mealmaker  soup

# %%
# 4. Create a NonVegfood_items.xlsx file  (atleast 10 names, columns are NonVegFoodName*Taste)
import pandas as pd
NonVegfood_items=pd.read_excel(r"C:\jaya sri\Assignments\Jayasri\Pandas_assign8\nonvegtaste.xlsx")
NonVegfood_items
# Out:
#      nonveg  taste
# 0   chicken    hot
# 1    mutton  salty
# 2      fish    fry
# 3    prawns  spicy
# 4  chicken     fry

# %%
# Q1>create a dataframe which contains only chicken items
NonVegfood_items[NonVegfood_items['nonveg']=="chicken"]
# Out:
#     nonveg taste
# 0  chicken   hot

# %%
# Q2>create a dataframe which contains only mutton items
NonVegfood_items[NonVegfood_items['nonveg']=="mutton"]
# Out:
#    nonveg  taste
# 1  mutton  salty

# %%
# Q3>create a dataframe which contains only Fry items
NonVegfood_items[NonVegfood_items['taste']=="fry"]
# Out:
#      nonveg taste
# 2      fish   fry
# 4  chicken    fry

# %%
# Q4>create a dataframe which contains only Fry or chicken items
NonVegfood_items[(NonVegfood_items['taste']=='fry') | (NonVegfood_items['nonveg']=='chicken')]
# Out:
#      nonveg taste
# 0   chicken   hot
# 2      fish   fry
# 4  chicken    fry

# %%
# Q5>create a dataframe which not contains Fry and chicken items
NonVegfood_items[~(NonVegfood_items['nonveg']=='chicken') & (NonVegfood_items['taste']=='fry')]
# Out:
#      nonveg taste
# 2      fish   fry
# 4  chicken    fry

# %%
# Q6>create a dataframe which contains either Fry or mutton items
NonVegfood_items[(NonVegfood_items['taste']=='fry') | (NonVegfood_items['nonveg']=='mutton')]
# Out:
#      nonveg  taste
# 1    mutton  salty
# 2      fish    fry
# 4  chicken     fry

# %%
# 5. Create a month_names.xlsx file (atleast 12 names, columns are MonthName*Season)
import pandas as pd
month_names=pd.read_excel(r"C:\jaya sri\Assignments\Jayasri\Pandas_assign8\MonthsandSeason.xlsx")
month_names
# Out:
#     MonthName  Season
# 0     January  Winter
# 1     Febuary  Winter
# 2       March  Winter
# 3       April  Summer
# 4         May  Summer
# 5        June  Summer
# 6        July  Summer
# 7      August   Rainy
# 8   September   Rainy
# 9     October   Rainy
# 10   November   Rainy
# 11   December  Winter

# %%
# Q1>create a dataframe which contains only winter season months
month_names[month_names['Season']=='Winter']
# Out:
#    MonthName  Season
# 0    January  Winter
# 1    Febuary  Winter
# 2      March  Winter
# 11  December  Winter

# %%
# Q2>create a dataframe which contains only summer season months
month_names[month_names['Season']=='Summer']
# Out:
#   MonthName  Season
# 3     April  Summer
# 4       May  Summer
# 5      June  Summer
# 6      July  Summer

# %%
# Q3>create a dataframe which contains only rainy season months
month_names[month_names['Season']=='Rainy']
# Out:
#     MonthName Season
# 7      August  Rainy
# 8   September  Rainy
# 9     October  Rainy
# 10   November  Rainy

# %%
# Q4>create a dataframe which contains only winter and summer season months
lst1=['Summer','Winter']
month_names[month_names.Season.isin(lst1)]
# Out:
#    MonthName  Season
# 0    January  Winter
# 1    Febuary  Winter
# 2      March  Winter
# 3      April  Summer
# 4        May  Summer
# 5       June  Summer
# 6       July  Summer
# 11  December  Winter

# %%
# Q5>create a dataframe which not contains summer and rainy season months
# month_names[~(month_names['Season']=='Summer') & (month_names['Season']=='Rainy')]
lst=['Summer','Rainy']
month_names[~month_names.Season.isin(lst)]
# Out:
#    MonthName  Season
# 0    January  Winter
# 1    Febuary  Winter
# 2      March  Winter
# 11  December  Winter

# %%
# Q6>create a dataframe which contains either winter or rainy
lst3=['Winter','Rainy']
month_names[month_names.Season.isin(lst3)]
# Out:
#     MonthName  Season
# 0     January  Winter
# 1     Febuary  Winter
# 2       March  Winter
# 7      August   Rainy
# 8   September   Rainy
# 9     October   Rainy
# 10   November   Rainy
# 11   December  Winter
